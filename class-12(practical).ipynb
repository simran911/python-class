# %%
#import libaray

import pandas as pd

# %%
#import the file you want to work on

movies=pd.read_csv('bollywood.csv')

# %%
movies["lead"]
# Out:
# 0          Vicky Kaushal
# 1            Vicky Ahuja
# 2            Anupam Kher
# 3          Emraan Hashmi
# 4       Mona Ambegaonkar
#               ...
# 1495      Shah Rukh Khan
# 1496    Amitabh Bachchan
# 1497        Vivek Oberoi
# 1498          Ajay Devgn
# 1499        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
#to see the top 5 values

movies.head(20)
# Out:
#                                    movie                  lead
# 0               Uri: The Surgical Strike         Vicky Kaushal
# 1                          Battalion 609           Vicky Ahuja
# 2   The Accidental Prime Minister (film)           Anupam Kher
# 3                        Why Cheat India         Emraan Hashmi
# 4                        Evening Shadows      Mona Ambegaonkar
# 5                            Soni (film)  Geetika Vidya Ohlyan
# 6                          Fraud Saiyaan          Arshad Warsi
# 7                             Bombairiya          Radhika Apte
# 8       Manikarnika: The Queen of Jhansi        Kangana Ranaut
# 9                       Thackeray (film)   Nawazuddin Siddiqui
# 10                                Amavas             Ali Asgar
# 11                             Gully Boy         Ranveer Singh
# 12                             Hum Chaar           Prit Kamani
# 13                         Total Dhamaal            Ajay Devgn
# ...

# %%
#to see the bottom 5 values

movies.tail(20)
# Out:
#                                  movie                 lead
# 1480  Rules: Pyaar Ka Superhit Formula               Tanuja
# 1481       Right Here Right Now (film)                Ankit
# 1482                Raja Bhaiya (film)  Sadashiv Amrapurkar
# 1483                         Tere Naam          Salman Khan
# 1484                  Tujhe Meri Kasam     Riteish Deshmukh
# 1485       Talaash: The Hunt Begins...        Rakhee Gulzar
# 1486               Tehzeeb (2003 film)         Shabana Azmi
# 1487                   The Pink Mirror      Edwin Fernandes
# 1488                           Yeh Dil       Tusshar Kapoor
# 1489                          Xcuse Me        Sharman Joshi
# 1490                  Raaz (2002 film)           Dino Morea
# 1491                Zameen (2003 film)           Ajay Devgn
# 1492        Waisa Bhi Hota Hai Part II         Arshad Warsi
# 1493          Devdas (2002 Hindi film)       Shah Rukh Khan
# 1494                            Kaante     Amitabh Bachchan
# ...

# %%
#Sample

movies.sample(20)
# Out:
#                                    movie                 lead
# 1403       The Hero: Love Story of a Spy           Sunny Deol
# 522                    Pizza (2014 film)        Akshay Oberoi
# 1361            Lakeer – Forbidden Lines           Sunny Deol
# 973   Rocket Singh: Salesman of the Year        Ranbir Kapoor
# 647                        Wake Up India         Elisha Kriis
# 16                Mard Ko Dard Nahi Hota     Abhimanyu Dasani
# 91                     Veerey Ki Wedding        Pulkit Samrat
# 238                     Secret Superstar          Zaira Wasim
# 988               Humne Jeena Seekh Liya        Omkar Bhatkar
# 837                     Right Yaaa Wrong           Sunny Deol
# 968                     Jail (2009 film)       Manoj Bajpayee
# 113                              Phamous      Jimmy Sheirgill
# 171            Rangoon (2017 Hindi film)       Kangana Ranaut
# 1468                         Matrubhoomi          Tulip Joshi
# ...

# %%
#value_count ->movies

movies.value_counts()
# Out:
# movie                     lead
# Andaaz                    Akshay Kumar        2
# Tanu Weds Manu: Returns   Kangana Ranaut      2
# Gabbar Is Back            Akshay Kumar        2
# 1920 (film)               Rajniesh Duggall    1
# Newton (film)             Rajkummar Rao       1
#                                              ..
# Ghayal: Once Again        Sunny Deol          1
# Ghanchakkar (film)        Vidya Balan         1
# Ghajini (2008 film)       Aamir Khan          1
# Genius (2018 Hindi film)  Utkarsh Sharma      1
# Zor Lagaa Ke...Haiya!     Meghan Jadhav       1
# Name: count, Length: 1497, dtype: int64

# %%
movies["movie"]
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1495                  Hum Tumhare Hain Sanam
# 1496                     Aankhen (2002 film)
# 1497                         Saathiya (film)
# 1498                          Company (film)
# 1499                    Awara Paagal Deewana
# Name: movie, Length: 1500, dtype: object

# %%
movies["lead"]
# Out:
# 0          Vicky Kaushal
# 1            Vicky Ahuja
# 2            Anupam Kher
# 3          Emraan Hashmi
# 4       Mona Ambegaonkar
#               ...
# 1495      Shah Rukh Khan
# 1496    Amitabh Bachchan
# 1497        Vivek Oberoi
# 1498          Ajay Devgn
# 1499        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies["lead"]=="Akshay"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# 1499    False
# Name: lead, Length: 1500, dtype: bool

# %%
Aamir_khan=movies['lead']=="Aamir Khan"

# %%
value=movies[Aamir_khan==True]

# %%
value
# Out:
#                                 movie        lead
# 166                Thugs of Hindostan  Aamir Khan
# 354                     Dangal (film)  Aamir Khan
# 568                         PK (film)  Aamir Khan
# 654                           Dhoom 3  Aamir Khan
# 729   Talaash: The Answer Lies Within  Aamir Khan
# 914                          3 Idiots  Aamir Khan
# 980               Ghajini (2008 film)  Aamir Khan
# 1168                Fanaa (2006 film)  Aamir Khan
# 1198                  Rang De Basanti  Aamir Khan
# 1279        Mangal Pandey: The Rising  Aamir Khan

# %% [markdown]
# [Aamir_khan=="True"]

# %%
value=movies[Aamir_khan==True]

# %%
value
# Out:
#                                 movie        lead
# 166                Thugs of Hindostan  Aamir Khan
# 354                     Dangal (film)  Aamir Khan
# 568                         PK (film)  Aamir Khan
# 654                           Dhoom 3  Aamir Khan
# 729   Talaash: The Answer Lies Within  Aamir Khan
# 914                          3 Idiots  Aamir Khan
# 980               Ghajini (2008 film)  Aamir Khan
# 1168                Fanaa (2006 film)  Aamir Khan
# 1198                  Rang De Basanti  Aamir Khan
# 1279        Mangal Pandey: The Rising  Aamir Khan

# %%
vk=pd.read_csv('kohli_ipl.csv')

# %%
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
vk["runs"]
# Out:
# 0       1
# 1      23
# 2      13
# 3      12
# 4       1
#        ..
# 210     0
# 211    20
# 212    73
# 213    25
# 214     7
# Name: runs, Length: 215, dtype: int64

# %%
#to sort values
df=vk.sort_values(by='runs',ascending=False)

# %%
df["runs"].head(50).sum()
# Out:
# 3511

# %%
vk.max()
# Out:
# match_no    215
# runs        113
# dtype: int64

# %%
# mean -> median -> mode -> std -> var
print(vk.mean())
print(vk.median())
print(movies.mode())
# Out:
# match_no    108.000000
# runs         30.855814
# dtype: float64
# match_no    108.0
# runs         24.0
# dtype: float64
#                      movie          lead
# 0                   Andaaz  Akshay Kumar
# 1           Gabbar Is Back           NaN
# 2  Tanu Weds Manu: Returns           NaN

# %%
vk.min()
# Out:
# match_no    1
# runs        0
# dtype: int64

# %%
vk.max()
# Out:
# match_no    215
# runs        113
# dtype: int64

# %%
vk.head(50)
# Out:
#     match_no  runs
# 0          1     1
# 1          2    23
# 2          3    13
# 3          4    12
# 4          5     1
# 5          6     9
# 6          7    34
# 7          8     0
# 8          9    21
# 9         10     3
# 10        11    10
# 11        12    38
# 12        13     3
# 13        14    11
# 14        15    50
# 15        16     2
# 16        17    22
# 17        18    19
# 18        19    16
# 19        20    15
# 20        21    20
# 21        22    38
# 22        23    19
# 23        24    24
# 24        25     7
# 25        26     2
# 26        27    16
# 27        28    17
# 28        29    24
# 29        30    38
# 30        31    34
# 31        32    42
# 32        33    13
# 33        34    58
# 34        35     3
# 35        36    14
# 36        37    37
# 37        38     9
# 38        39    23
# 39        40    12
# 40        41    71
# 41        42    35
# 42        43    30
# 43        44    56
# 44        45    67
# 45        46    27
# ...

# %%
vk.head(50)["runs"].sum()
# Out:
# 1131

# %%
#to have the whole mathematics information about a dataset
vk.describe()
# Out:
#          match_no        runs
# count  215.000000  215.000000
# mean   108.000000   30.855814
# std     62.209324   26.229801
# min      1.000000    0.000000
# 25%     54.500000    9.000000
# 50%    108.000000   24.000000
# 75%    161.500000   48.000000
# max    215.000000  113.000000

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
